# %% [markdown]
# # EDA — Telemetry Anomaly Detection
#
# Explore the SMAP/MSL telemetry channels before modeling: shape, missing data, value ranges, and a first look at labeled anomaly windows.

# %%
import sys
sys.path.insert(0, '../src')

import matplotlib.pyplot as plt
from data_loader import load_channel

# TODO: run data_loader.download_data() first, then load a channel
# arr = load_channel('A-1', split='train')
# arr.shape

# %%
# TODO: plot a few channels over time, mark labeled anomaly windows in red
# plt.figure(figsize=(12, 4))
# plt.plot(arr[:, 0])
# plt.title('Channel A-1, feature 0')
# plt.show()
